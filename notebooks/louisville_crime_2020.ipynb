# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importing Louisville Crime Data
louisville_crime_2020 = pd.read_csv('../data/crime_2020_-2988378996369536818.csv')
louisville_crime_2020
# Out:
# C:\Users\Joe\AppData\Local\Temp\ipykernel_11616\3099630620.py:2: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   louisville_crime_2020 = pd.read_csv('../data/crime_2020_-2988378996369536818.csv')
#       INCIDENT_NUMBER        DATE_REPORTED         DATE_OCCURED  \
# 0        80-20-000117  2020-01-01 13:50:00  2019-12-31 03:30:00
# 1        80-20-000292  2020-01-02 10:45:00  2019-12-31 18:00:00
# 2        80-19-096135  2020-01-01 00:26:00  2019-12-31 23:30:00
# 3        80-20-000234  2020-01-01 23:57:00  2020-01-01 03:00:00
# 4        80-20-000294  2020-01-02 11:02:00  2019-12-31 12:00:00
# ...               ...                  ...                  ...
# 70228    80-20-077551  2020-12-31 16:09:00  2020-12-31 15:00:00
# 70229    80-20-077552  2020-12-31 15:38:00  2020-12-31 14:25:00
# 70230    80-20-077554  2020-12-31 16:25:00  2020-12-31 00:01:00
# 70231    80-20-077553  2020-12-31 15:39:00  2020-12-31 15:34:00
# 70232    80-20-077555  2020-12-31 16:26:00  2020-12-30 20:30:00
#
#                    CRIME_TYPE  \
# 0                       FRAUD
# 1               THEFT/LARCENY
# 2      VEHICLE BREAK-IN/THEFT
# 3                   VANDALISM
# 4      VEHICLE BREAK-IN/THEFT
# ...                       ...
# 70228  VEHICLE BREAK-IN/THEFT
# 70229                 ASSAULT
# 70230  VEHICLE BREAK-IN/THEFT
# 70231                 ASSAULT
# 70232  VEHICLE BREAK-IN/THEFT
#
#                                                 UOR_DESC NIBRS_CODE  \
# 0      FRAUD USE OF CREDIT CARD AFTER REPT LOST/STOLE...        26B
# 1           TBUT OR DISP ALL OTHERS > $500 BUT < $10,000        23H
# 2      TBUT OR DISP CONTENTS FROM VEH $500 OR > BUT <...        23F
# 3                           CRIMINAL MISCHIEF-2ND DEGREE        290
# 4      TBUT OR DISP CONTENTS FROM VEH $500 OR > BUT <...        23F
# ...                                                  ...        ...
# 70228              TBUT OR DISP CONTENTS FROM VEH < $500        23F
# 70229  ASSAULT - 4TH DEGREE (DOMESTIC VIOLENCE) MINOR...        13B
# 70230              TBUT OR DISP CONTENTS FROM VEH < $500        23F
# 70231          HARASSMENT - PHYSICAL CONTACT - NO INJURY        13B
# 70232  TBUT OR DISP CONTENTS FROM VEH $500 OR > BUT <...        23F
#
#       UCR_HIERARCHY   ATT_COMP LMPD_DIVISION LMPD_BEAT  \
# 0           PART II  COMPLETED  4TH DIVISION       435
# 1            PART I  COMPLETED  6TH DIVISION       613
# 2            PART I  COMPLETED  1ST DIVISION       112
# 3           PART II  COMPLETED  4TH DIVISION       424
# 4            PART I  COMPLETED  7TH DIVISION       736
# ...             ...        ...           ...       ...
# 70228        PART I  COMPLETED  5TH DIVISION       525
# 70229       PART II  COMPLETED  2ND DIVISION       225
# 70230        PART I  COMPLETED  7TH DIVISION       723
# 70231       PART II  COMPLETED  3RD DIVISION       331
# 70232        PART I  COMPLETED  8TH DIVISION       824
#
#                                         PREMISE_TYPE  \
# 0      SERVICE / GAS STATION
# 1      NON-ATTACHED RESD GARAGE/SHED/BULD
# 2      HIGHWAY / ROAD / ALLEY
# 3      HIGHWAY / ROAD / ALLEY
# 4      DOCK/WHARF/FREIGHT/MODAL TERMINAL
# ...                                              ...
# 70228  PARKING LOT / GARAGE
# 70229  OTHER / UNKNOWN
# 70230  RESIDENCE / HOME
# 70231  RESIDENCE / HOME
# 70232  RESIDENCE / HOME
#
#                                            BLOCK_ADDRESS        City ZIP_CODE  \
# 0      4100 BLOCK TAYLOR BLVD                        ...  LOUISVILLE    40215
# 1      5200 BLOCK RUSSETT BLVD                       ...  LOUISVILLE    40218
# 2      S 16TH ST / W CHESTNUT ST                     ...  LOUISVILLE    40203
# 3      2700 BLOCK S 4TH ST                           ...  LOUISVILLE    40208
# 4      1800 BLOCK SOUTH PARK RD                      ...  LOUISVILLE    40219
# ...                                                  ...         ...      ...
# 70228  700 BLOCK COCHRAN HILL RD                     ...  LOUISVILLE  40206.0
# 70229  1600 BLOCK MOORE CT                           ...  LOUISVILLE  40210.0
# 70230  7600 BLOCK AVALON GARDEN DR                   ...  LOUISVILLE  40228.0
# 70231  3300 BLOCK RENWOOD BLVD                       ...  LOUISVILLE  40214.0
# 70232  12600 BLOCK OLD HENRY RD                      ...  LOUISVILLE  40223.0
#
#        ObjectId
# 0             1
# 1             2
# 2             3
# 3             4
# 4             5
# ...         ...
# 70228     70229
# 70229     70230
# 70230     70231
# 70231     70232
# 70232     70233
#
# [70233 rows x 15 columns]

# %%
# Creating a DataFrame from the Louisville Crime Data CSV file
crime_df = louisville_crime_2020
crime_df.head()
# Out:
#   INCIDENT_NUMBER        DATE_REPORTED         DATE_OCCURED  \
# 0    80-20-000117  2020-01-01 13:50:00  2019-12-31 03:30:00
# 1    80-20-000292  2020-01-02 10:45:00  2019-12-31 18:00:00
# 2    80-19-096135  2020-01-01 00:26:00  2019-12-31 23:30:00
# 3    80-20-000234  2020-01-01 23:57:00  2020-01-01 03:00:00
# 4    80-20-000294  2020-01-02 11:02:00  2019-12-31 12:00:00
#
#                CRIME_TYPE                                           UOR_DESC  \
# 0                   FRAUD  FRAUD USE OF CREDIT CARD AFTER REPT LOST/STOLE...
# 1           THEFT/LARCENY       TBUT OR DISP ALL OTHERS > $500 BUT < $10,000
# 2  VEHICLE BREAK-IN/THEFT  TBUT OR DISP CONTENTS FROM VEH $500 OR > BUT <...
# 3               VANDALISM                       CRIMINAL MISCHIEF-2ND DEGREE
# 4  VEHICLE BREAK-IN/THEFT  TBUT OR DISP CONTENTS FROM VEH $500 OR > BUT <...
#
#   NIBRS_CODE UCR_HIERARCHY   ATT_COMP LMPD_DIVISION LMPD_BEAT  \
# 0        26B       PART II  COMPLETED  4TH DIVISION       435
# 1        23H        PART I  COMPLETED  6TH DIVISION       613
# 2        23F        PART I  COMPLETED  1ST DIVISION       112
# 3        290       PART II  COMPLETED  4TH DIVISION       424
# 4        23F        PART I  COMPLETED  7TH DIVISION       736
#
#                                     PREMISE_TYPE  \
# 0  SERVICE / GAS STATION
# 1  NON-ATTACHED RESD GARAGE/SHED/BULD
# 2  HIGHWAY / ROAD / ALLEY
# 3  HIGHWAY / ROAD / ALLEY
# 4  DOCK/WHARF/FREIGHT/MODAL TERMINAL
#
#                                        BLOCK_ADDRESS        City ZIP_CODE  \
# 0  4100 BLOCK TAYLOR BLVD                        ...  LOUISVILLE    40215
# 1  5200 BLOCK RUSSETT BLVD                       ...  LOUISVILLE    40218
# 2  S 16TH ST / W CHESTNUT ST                     ...  LOUISVILLE    40203
# 3  2700 BLOCK S 4TH ST                           ...  LOUISVILLE    40208
# 4  1800 BLOCK SOUTH PARK RD                      ...  LOUISVILLE    40219
#
#    ObjectId
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5

# %%
#Importing US Census Data
us_census_data = pd.read_csv('../data/US_Census_data_Louisville_socio-economic_by_ZIP_Code.csv')
us_census_data
# Out:
#     ZIP_Code  Total_Estd_Population  Income_<_Poverty_level  Inc-<-PL_Male  \
# 0      40023                   3692                     179             52
# 1      40025                     83                       0              0
# 2      40056                   2269                      45             28
# 3      40059                  14348                     194             71
# 4      40118                   6338                     643            195
# 5      40177                   1147                     285            128
# 6      40202                   4326                    2078           1280
# 7      40203                  11696                    3914           1733
# 8      40204                  10937                    1096            484
# 9      40205                  17108                     934            423
# 10     40206                  14681                    1419            733
# 11     40207                  22317                    1210            301
# 12     40208                   6448                    1494            767
# 13     40209                    315                      15              0
# 14     40210                   8503                    2749            907
# 15     40211                  13859                    3890           1310
# 16     40212                  10737                    3303           1168
# 17     40213                  11026                    1336            534
# 18     40214                  30234                    4448           1879
# 19     40215                  12870                    3079           1283
# 20     40216                  28803                    4091           1342
# 21     40217                   9447                    1021            636
# 22     40218                  23164                    2612           1083
# 23     40219                  26284                    2575           1018
# 24     40220                  24950                    1507            521
# 25     40222                  16236                    1004            405
# 26     40223                  16398                     461            106
# 27     40228                  11360                     828            438
# 28     40229                  27875                    2372            808
# 29     40231                      0                       0              0
# 30     40241                  21328                     725            251
# 31     40242                   8183                     486            221
# 32     40243                   7863                     398            103
# 33     40245                  22954                    1117            373
# 34     40258                  18017                    1510            567
# 35     40272                  25992                    2555            710
# 36     40280                    189                      47             24
# 37     40291                  26911                    1304            493
# 38     40299                  29437                    1137            301
#
#     Inc-<-PL_Male_Not-high-school-grad  Inc-<-PL_Male_High-school-grad  \
# 0                                    0                               0
# 1                                    0                               0
# 2                                    0                               6
# 3                                    0                              10
# 4                                   36                             115
# 5                                   15                              89
# 6                                  200                             706
# 7                                  405                             768
# 8                                   53                             134
# 9                                  121                              46
# 10                                 126                             233
# 11                                  27                              71
# 12                                 348                             143
# 13                                   0                               0
# 14                                 344                             381
# 15                                 438                             597
# 16                                 348                             565
# 17                                 169                             159
# 18                                 439                             619
# 19                                 354                             574
# 20                                 319                             741
# 21                                  60                             118
# 22                                 280                             401
# 23                                 256                             516
# 24                                  78                             103
# 25                                  52                             100
# 26                                  21                               5
# 27                                 109                              69
# 28                                 233                             218
# 29                                   0                               0
# 30                                  18                              94
# 31                                  56                              52
# 32                                   1                              35
# 33                                  17                              68
# 34                                  53                             329
# 35                                 213                             345
# 36                                   0                               0
# 37                                 103                             166
# 38                                   9                             190
#
#     Inc-<-PL_Male_Some-college-associates  Inc-<-PL_Male_Bachelors-higher  \
# 0                                      52                               0
# 1                                       0                               0
# 2                                      22                               0
# 3                                      53                               8
# 4                                      44                               0
# 5                                      23                               1
# 6                                     365                               9
# 7                                     487                              73
# 8                                     198                              99
# 9                                      88                             168
# 10                                    174                             200
# 11                                     53                             150
# 12                                    150                             126
# 13                                      0                               0
# 14                                    172                              10
# 15                                    213                              62
# 16                                    209                              46
# 17                                    126                              80
# 18                                    575                             246
# 19                                    303                              52
# 20                                    235                              47
# 21                                    131                             327
# 22                                    205                             197
# 23                                    195                              51
# 24                                     90                             250
# 25                                    110                             143
# 26                                     34                              46
# 27                                    228                              32
# 28                                    300                              57
# 29                                      0                               0
# 30                                     90                              49
# 31                                     74                              39
# 32                                     10                              57
# 33                                     88                             200
# 34                                    154                              31
# 35                                    117                              35
# 36                                      0                              24
# 37                                    195                              29
# 38                                     65                              37
#
#     Inc-<-PL_Female  Inc-<-PL_Female_Not-high-school-grad  ...  \
# 0               127                                     0  ...
# 1                 0                                     0  ...
# 2                17                                    14  ...
# 3               123                                    47  ...
# 4               448                                    82  ...
# 5               157                                    44  ...
# 6               798                                    96  ...
# 7              2181                                   708  ...
# 8               612                                    88  ...
# 9               511                                    40  ...
# 10              686                                    44  ...
# 11              909                                    67  ...
# 12              727                                   153  ...
# 13               15                                     0  ...
# 14             1842                                   637  ...
# 15             2580                                   632  ...
# 16             2135                                   664  ...
# 17              802                                   181  ...
# 18             2569                                   667  ...
# 19             1796                                   548  ...
# 20             2749                                   809  ...
# 21              385                                    86  ...
# 22             1529                                   291  ...
# 23             1557                                   307  ...
# 24              986                                   201  ...
# 25              599                                    80  ...
# 26              355                                    46  ...
# 27              390                                    98  ...
# 28             1564                                   472  ...
# 29                0                                     0  ...
# 30              474                                    68  ...
# 31              265                                    26  ...
# 32              295                                    34  ...
# 33              744                                   127  ...
# 34              943                                   261  ...
# 35             1845                                   513  ...
# 36               23                                     0  ...
# 37              811                                    54  ...
# 38              836                                   172  ...
#
#     Inc->=-PL_Male  Inc->=-PL_Male_Not-high-school-grad  \
# 0             1921                                   86
# 1               41                                    0
# 2             1028                                   32
# 3             6780                                   63
# 4             2894                                  746
# 5              455                                  129
# 6             1070                                   74
# 7             3906                                  318
# 8             5224                                  191
# 9             7896                                  162
# 10            6505                                  398
# 11           10181                                  228
# 12            2597                                  196
# 13              61                                    7
# 14            2523                                  361
# 15            3705                                  601
# 16            3431                                  570
# 17            4813                                  555
# 18           13115                                 1920
# 19            5144                                 1034
# 20           11267                                 1296
# 21            3945                                  191
# 22           10727                                  984
# 23           11588                                 1394
# 24           10814                                  364
# 25            7372                                  197
# 26            7571                                  250
# 27            5002                                  357
# 28           12712                                 1020
# 29               0                                    0
# 30            9751                                  363
# 31            3620                                  217
# 32            3489                                   70
# 33           10343                                  244
# 34            7804                                  802
# 35           11142                                 1503
# 36              77                                    0
# 37           12037                                  629
# 38           13619                                  656
#
#     Inc->=-PL_Male_High-school-grad  Inc->=-PL_Male_Some-college-associates  \
# 0                               557                                     558
# 1                                 0                                       0
# 2                               111                                     402
# 3                               425                                    1176
# 4                              1305                                     623
# 5                               163                                      83
# 6                               273                                     249
# 7                              1058                                    1413
# 8                               841                                    1407
# 9                               744                                    1835
# 10                             1032                                    1434
# 11                              983                                    1809
# 12                              646                                     907
# 13                               18                                      30
# 14                              852                                    1167
# 15                             1766                                    1110
# 16                             1843                                     641
# 17                             1472                                    1721
# 18                             4478                                    4262
# 19                             2084                                    1577
# 20                             4649                                    3967
# 21                             1212                                    1022
# 22                             3681                                    3276
# 23                             4559                                    3622
# 24                             1863                                    3786
# 25                              982                                    1792
# 26                              879                                    1841
# 27                             1486                                    1925
# 28                             5140                                    4569
# 29                                0                                       0
# 30                             1451                                    2235
# 31                              619                                    1146
# 32                              549                                     909
# 33                              774                                    2531
# 34                             3324                                    2932
# 35                             4180                                    3827
# 36                                0                                       9
# 37                             3097                                    4162
# 38                             2947                                    4548
#
#     Inc->=-PL_Male_Bachelors-higher  Inc->=-PL_Female  \
# 0                               720              1592
# 1                                41                42
# 2                               483              1196
# 3                              5116              7374
# 4                               220              2801
# 5                                80               407
# 6                               474              1178
# 7                              1117              3876
# 8                              2785              4617
# 9                              5155              8278
# 10                             3641              6757
# 11                             7161             10926
# 12                              848              2357
# 13                                6               239
# 14                              143              3231
# 15                              228              6264
# 16                              377              4003
# 17                             1065              4877
# 18                             2455             12671
# 19                              449              4647
# 20                             1355             13445
# 21                             1520              4481
# 22                             2786              9825
# 23                             2013             12121
# 24                             4801             12629
# 25                             4401              7860
# 26                             4601              8366
# 27                             1234              5530
# 28                             1983             12791
# 29                                0                 0
# 30                             5702             10852
# 31                             1638              4077
# 32                             1961              3976
# 33                             6794             11494
# 34                              746              8703
# 35                             1632             12295
# 36                               68                65
# 37                             4149             13570
# 38                             5468             14681
#
#     Inc->=-PL_Female_Not-high-school-grad  Inc->=-PL_Female_High-school-grad  \
# 0                                      67                                329
# 1                                       0                                  0
# 2                                      26                                252
# 3                                     121                                640
# 4                                     309                               1194
# 5                                      22                                187
# 6                                     140                                240
# 7                                     207                                900
# 8                                     123                                659
# 9                                     190                                967
# 10                                    329                               1015
# 11                                    162                               1123
# 12                                    190                                583
# 13                                    125                                 17
# 14                                    316                                908
# 15                                   1054                               1672
# 16                                    596                               1405
# 17                                    393                               1373
# 18                                   1495                               3595
# 19                                    747                               1533
# 20                                   1752                               5213
# 21                                    251                                868
# 22                                    889                               2588
# 23                                   1452                               3847
# 24                                    358                               2748
# 25                                    197                                849
# 26                                    236                               1554
# 27                                    210                               1510
# 28                                    995                               4927
# 29                                      0                                  0
# 30                                    264                               1376
# 31                                    198                                566
# 32                                    105                                692
# 33                                    311                               1329
# 34                                    879                               3149
# 35                                   1105                               4772
# 36                                      0                                 33
# 37                                    502                               3596
# 38                                    555                               3607
#
#     Inc->=-PL_Female_Some-college-associates  \
# 0                                        413
# 1                                         10
# 2                                        341
# 3                                       1497
# 4                                        728
# 5                                        118
# 6                                        300
# 7                                       1525
# 8                                       1092
# 9                                       1717
# 10                                      1451
# 11                                      2449
# 12                                       899
# 13                                        86
# 14                                      1657
# 15                                      2823
# 16                                      1452
# 17                                      1776
# 18                                      4216
# 19                                      1773
# 20                                      4111
# 21                                      1346
# 22                                      3688
# 23                                      4154
# 24                                      4457
# 25                                      2250
# 26                                      2265
# 27                                      2243
# 28                                      4576
# 29                                         0
# 30                                      3343
# 31                                      1297
# 32                                      1516
# 33                                      3150
# 34                                      3147
# 35                                      3927
# 36                                         0
# 37                                      4659
# 38                                      4567
#
#     Inc->=-PL_Female_Bachelors-higher
# 0                                 783
# 1                                  32
# 2                                 577
# 3                                5116
# 4                                 570
# 5                                  80
# 6                                 498
# 7                                1244
# 8                                2743
# 9                                5404
# 10                               3962
# 11                               7192
# 12                                685
# 13                                 11
# 14                                350
# 15                                715
# 16                                550
# 17                               1335
# 18                               3365
# 19                                594
# 20                               2369
# 21                               2016
# 22                               2660
# 23                               2668
# 24                               5066
# 25                               4564
# 26                               4311
# 27                               1567
# 28                               2293
# 29                                  0
# 30                               5869
# 31                               2016
# 32                               1663
# 33                               6704
# 34                               1528
# 35                               2491
# 36                                 32
# 37                               4813
# 38                               5952
#
# [39 rows x 24 columns]

# %%
#Creating a DataFrame from the US Census Data CSV file
census_df = us_census_data
census_df.head()
# Out:
#    ZIP_Code  Total_Estd_Population  Income_<_Poverty_level  Inc-<-PL_Male  \
# 0     40023                   3692                     179             52
# 1     40025                     83                       0              0
# 2     40056                   2269                      45             28
# 3     40059                  14348                     194             71
# 4     40118                   6338                     643            195
#
#    Inc-<-PL_Male_Not-high-school-grad  Inc-<-PL_Male_High-school-grad  \
# 0                                   0                               0
# 1                                   0                               0
# 2                                   0                               6
# 3                                   0                              10
# 4                                  36                             115
#
#    Inc-<-PL_Male_Some-college-associates  Inc-<-PL_Male_Bachelors-higher  \
# 0                                     52                               0
# 1                                      0                               0
# 2                                     22                               0
# 3                                     53                               8
# 4                                     44                               0
#
#    Inc-<-PL_Female  Inc-<-PL_Female_Not-high-school-grad  ...  Inc->=-PL_Male  \
# 0              127                                     0  ...            1921
# 1                0                                     0  ...              41
# 2               17                                    14  ...            1028
# 3              123                                    47  ...            6780
# 4              448                                    82  ...            2894
#
#    Inc->=-PL_Male_Not-high-school-grad  Inc->=-PL_Male_High-school-grad  \
# 0                                   86                              557
# 1                                    0                                0
# 2                                   32                              111
# 3                                   63                              425
# 4                                  746                             1305
#
#    Inc->=-PL_Male_Some-college-associates  Inc->=-PL_Male_Bachelors-higher  \
# 0                                     558                              720
# 1                                       0                               41
# 2                                     402                              483
# 3                                    1176                             5116
# 4                                     623                              220
#
#    Inc->=-PL_Female  Inc->=-PL_Female_Not-high-school-grad  \
# 0              1592                                     67
# 1                42                                      0
# 2              1196                                     26
# 3              7374                                    121
# 4              2801                                    309
#
#    Inc->=-PL_Female_High-school-grad  \
# 0                                329
# 1                                  0
# 2                                252
# 3                                640
# 4                               1194
#
#    Inc->=-PL_Female_Some-college-associates  Inc->=-PL_Female_Bachelors-higher
# 0                                       413                                783
# 1                                        10                                 32
# 2                                       341                                577
# 3                                      1497                               5116
# 4                                       728                                570
#
# [5 rows x 24 columns]

# %%
#Changing data type of 'ZIP_Code' in Census Data to match that of 'Zip_Code' in Crime Data for comparison

census_df['ZIP_Code'] = census_df['ZIP_Code'].astype(str)
census_df
# Out:
#    ZIP_Code  Total_Estd_Population  Income_<_Poverty_level  Inc-<-PL_Male  \
# 0     40023                   3692                     179             52
# 1     40025                     83                       0              0
# 2     40056                   2269                      45             28
# 3     40059                  14348                     194             71
# 4     40118                   6338                     643            195
# 5     40177                   1147                     285            128
# 6     40202                   4326                    2078           1280
# 7     40203                  11696                    3914           1733
# 8     40204                  10937                    1096            484
# 9     40205                  17108                     934            423
# 10    40206                  14681                    1419            733
# 11    40207                  22317                    1210            301
# 12    40208                   6448                    1494            767
# 13    40209                    315                      15              0
# 14    40210                   8503                    2749            907
# 15    40211                  13859                    3890           1310
# 16    40212                  10737                    3303           1168
# 17    40213                  11026                    1336            534
# 18    40214                  30234                    4448           1879
# 19    40215                  12870                    3079           1283
# 20    40216                  28803                    4091           1342
# 21    40217                   9447                    1021            636
# 22    40218                  23164                    2612           1083
# 23    40219                  26284                    2575           1018
# 24    40220                  24950                    1507            521
# 25    40222                  16236                    1004            405
# 26    40223                  16398                     461            106
# 27    40228                  11360                     828            438
# 28    40229                  27875                    2372            808
# 29    40231                      0                       0              0
# 30    40241                  21328                     725            251
# 31    40242                   8183                     486            221
# 32    40243                   7863                     398            103
# 33    40245                  22954                    1117            373
# 34    40258                  18017                    1510            567
# 35    40272                  25992                    2555            710
# 36    40280                    189                      47             24
# 37    40291                  26911                    1304            493
# 38    40299                  29437                    1137            301
#
#     Inc-<-PL_Male_Not-high-school-grad  Inc-<-PL_Male_High-school-grad  \
# 0                                    0                               0
# 1                                    0                               0
# 2                                    0                               6
# 3                                    0                              10
# 4                                   36                             115
# 5                                   15                              89
# 6                                  200                             706
# 7                                  405                             768
# 8                                   53                             134
# 9                                  121                              46
# 10                                 126                             233
# 11                                  27                              71
# 12                                 348                             143
# 13                                   0                               0
# 14                                 344                             381
# 15                                 438                             597
# 16                                 348                             565
# 17                                 169                             159
# 18                                 439                             619
# 19                                 354                             574
# 20                                 319                             741
# 21                                  60                             118
# 22                                 280                             401
# 23                                 256                             516
# 24                                  78                             103
# 25                                  52                             100
# 26                                  21                               5
# 27                                 109                              69
# 28                                 233                             218
# 29                                   0                               0
# 30                                  18                              94
# 31                                  56                              52
# 32                                   1                              35
# 33                                  17                              68
# 34                                  53                             329
# 35                                 213                             345
# 36                                   0                               0
# 37                                 103                             166
# 38                                   9                             190
#
#     Inc-<-PL_Male_Some-college-associates  Inc-<-PL_Male_Bachelors-higher  \
# 0                                      52                               0
# 1                                       0                               0
# 2                                      22                               0
# 3                                      53                               8
# 4                                      44                               0
# 5                                      23                               1
# 6                                     365                               9
# 7                                     487                              73
# 8                                     198                              99
# 9                                      88                             168
# 10                                    174                             200
# 11                                     53                             150
# 12                                    150                             126
# 13                                      0                               0
# 14                                    172                              10
# 15                                    213                              62
# 16                                    209                              46
# 17                                    126                              80
# 18                                    575                             246
# 19                                    303                              52
# 20                                    235                              47
# 21                                    131                             327
# 22                                    205                             197
# 23                                    195                              51
# 24                                     90                             250
# 25                                    110                             143
# 26                                     34                              46
# 27                                    228                              32
# 28                                    300                              57
# 29                                      0                               0
# 30                                     90                              49
# 31                                     74                              39
# 32                                     10                              57
# 33                                     88                             200
# 34                                    154                              31
# 35                                    117                              35
# 36                                      0                              24
# 37                                    195                              29
# 38                                     65                              37
#
#     Inc-<-PL_Female  Inc-<-PL_Female_Not-high-school-grad  ...  \
# 0               127                                     0  ...
# 1                 0                                     0  ...
# 2                17                                    14  ...
# 3               123                                    47  ...
# 4               448                                    82  ...
# 5               157                                    44  ...
# 6               798                                    96  ...
# 7              2181                                   708  ...
# 8               612                                    88  ...
# 9               511                                    40  ...
# 10              686                                    44  ...
# 11              909                                    67  ...
# 12              727                                   153  ...
# 13               15                                     0  ...
# 14             1842                                   637  ...
# 15             2580                                   632  ...
# 16             2135                                   664  ...
# 17              802                                   181  ...
# 18             2569                                   667  ...
# 19             1796                                   548  ...
# 20             2749                                   809  ...
# 21              385                                    86  ...
# 22             1529                                   291  ...
# 23             1557                                   307  ...
# 24              986                                   201  ...
# 25              599                                    80  ...
# 26              355                                    46  ...
# 27              390                                    98  ...
# 28             1564                                   472  ...
# 29                0                                     0  ...
# 30              474                                    68  ...
# 31              265                                    26  ...
# 32              295                                    34  ...
# 33              744                                   127  ...
# 34              943                                   261  ...
# 35             1845                                   513  ...
# 36               23                                     0  ...
# 37              811                                    54  ...
# 38              836                                   172  ...
#
#     Inc->=-PL_Male  Inc->=-PL_Male_Not-high-school-grad  \
# 0             1921                                   86
# 1               41                                    0
# 2             1028                                   32
# 3             6780                                   63
# 4             2894                                  746
# 5              455                                  129
# 6             1070                                   74
# 7             3906                                  318
# 8             5224                                  191
# 9             7896                                  162
# 10            6505                                  398
# 11           10181                                  228
# 12            2597                                  196
# 13              61                                    7
# 14            2523                                  361
# 15            3705                                  601
# 16            3431                                  570
# 17            4813                                  555
# 18           13115                                 1920
# 19            5144                                 1034
# 20           11267                                 1296
# 21            3945                                  191
# 22           10727                                  984
# 23           11588                                 1394
# 24           10814                                  364
# 25            7372                                  197
# 26            7571                                  250
# 27            5002                                  357
# 28           12712                                 1020
# 29               0                                    0
# 30            9751                                  363
# 31            3620                                  217
# 32            3489                                   70
# 33           10343                                  244
# 34            7804                                  802
# 35           11142                                 1503
# 36              77                                    0
# 37           12037                                  629
# 38           13619                                  656
#
#     Inc->=-PL_Male_High-school-grad  Inc->=-PL_Male_Some-college-associates  \
# 0                               557                                     558
# 1                                 0                                       0
# 2                               111                                     402
# 3                               425                                    1176
# 4                              1305                                     623
# 5                               163                                      83
# 6                               273                                     249
# 7                              1058                                    1413
# 8                               841                                    1407
# 9                               744                                    1835
# 10                             1032                                    1434
# 11                              983                                    1809
# 12                              646                                     907
# 13                               18                                      30
# 14                              852                                    1167
# 15                             1766                                    1110
# 16                             1843                                     641
# 17                             1472                                    1721
# 18                             4478                                    4262
# 19                             2084                                    1577
# 20                             4649                                    3967
# 21                             1212                                    1022
# 22                             3681                                    3276
# 23                             4559                                    3622
# 24                             1863                                    3786
# 25                              982                                    1792
# 26                              879                                    1841
# 27                             1486                                    1925
# 28                             5140                                    4569
# 29                                0                                       0
# 30                             1451                                    2235
# 31                              619                                    1146
# 32                              549                                     909
# 33                              774                                    2531
# 34                             3324                                    2932
# 35                             4180                                    3827
# 36                                0                                       9
# 37                             3097                                    4162
# 38                             2947                                    4548
#
#     Inc->=-PL_Male_Bachelors-higher  Inc->=-PL_Female  \
# 0                               720              1592
# 1                                41                42
# 2                               483              1196
# 3                              5116              7374
# 4                               220              2801
# 5                                80               407
# 6                               474              1178
# 7                              1117              3876
# 8                              2785              4617
# 9                              5155              8278
# 10                             3641              6757
# 11                             7161             10926
# 12                              848              2357
# 13                                6               239
# 14                              143              3231
# 15                              228              6264
# 16                              377              4003
# 17                             1065              4877
# 18                             2455             12671
# 19                              449              4647
# 20                             1355             13445
# 21                             1520              4481
# 22                             2786              9825
# 23                             2013             12121
# 24                             4801             12629
# 25                             4401              7860
# 26                             4601              8366
# 27                             1234              5530
# 28                             1983             12791
# 29                                0                 0
# 30                             5702             10852
# 31                             1638              4077
# 32                             1961              3976
# 33                             6794             11494
# 34                              746              8703
# 35                             1632             12295
# 36                               68                65
# 37                             4149             13570
# 38                             5468             14681
#
#     Inc->=-PL_Female_Not-high-school-grad  Inc->=-PL_Female_High-school-grad  \
# 0                                      67                                329
# 1                                       0                                  0
# 2                                      26                                252
# 3                                     121                                640
# 4                                     309                               1194
# 5                                      22                                187
# 6                                     140                                240
# 7                                     207                                900
# 8                                     123                                659
# 9                                     190                                967
# 10                                    329                               1015
# 11                                    162                               1123
# 12                                    190                                583
# 13                                    125                                 17
# 14                                    316                                908
# 15                                   1054                               1672
# 16                                    596                               1405
# 17                                    393                               1373
# 18                                   1495                               3595
# 19                                    747                               1533
# 20                                   1752                               5213
# 21                                    251                                868
# 22                                    889                               2588
# 23                                   1452                               3847
# 24                                    358                               2748
# 25                                    197                                849
# 26                                    236                               1554
# 27                                    210                               1510
# 28                                    995                               4927
# 29                                      0                                  0
# 30                                    264                               1376
# 31                                    198                                566
# 32                                    105                                692
# 33                                    311                               1329
# 34                                    879                               3149
# 35                                   1105                               4772
# 36                                      0                                 33
# 37                                    502                               3596
# 38                                    555                               3607
#
#     Inc->=-PL_Female_Some-college-associates  \
# 0                                        413
# 1                                         10
# 2                                        341
# 3                                       1497
# 4                                        728
# 5                                        118
# 6                                        300
# 7                                       1525
# 8                                       1092
# 9                                       1717
# 10                                      1451
# 11                                      2449
# 12                                       899
# 13                                        86
# 14                                      1657
# 15                                      2823
# 16                                      1452
# 17                                      1776
# 18                                      4216
# 19                                      1773
# 20                                      4111
# 21                                      1346
# 22                                      3688
# 23                                      4154
# 24                                      4457
# 25                                      2250
# 26                                      2265
# 27                                      2243
# 28                                      4576
# 29                                         0
# 30                                      3343
# 31                                      1297
# 32                                      1516
# 33                                      3150
# 34                                      3147
# 35                                      3927
# 36                                         0
# 37                                      4659
# 38                                      4567
#
#     Inc->=-PL_Female_Bachelors-higher
# 0                                 783
# 1                                  32
# 2                                 577
# 3                                5116
# 4                                 570
# 5                                  80
# 6                                 498
# 7                                1244
# 8                                2743
# 9                                5404
# 10                               3962
# 11                               7192
# 12                                685
# 13                                 11
# 14                                350
# 15                                715
# 16                                550
# 17                               1335
# 18                               3365
# 19                                594
# 20                               2369
# 21                               2016
# 22                               2660
# 23                               2668
# 24                               5066
# 25                               4564
# 26                               4311
# 27                               1567
# 28                               2293
# 29                                  0
# 30                               5869
# 31                               2016
# 32                               1663
# 33                               6704
# 34                               1528
# 35                               2491
# 36                                 32
# 37                               4813
# 38                               5952
#
# [39 rows x 24 columns]

# %%
# Print Crime Data column names
crime_df.columns
# Out:
# Index(['Incident_Number', 'Date_Reported', 'Date_Occurred', 'Crime_Type',
#        'UOR_Offense_Description', 'NIBRS_Code', 'UCR_Hierarchy', 'Att_Comp',
#        'LMPD_Division', 'LMPD_Beat', 'Premise_Type', 'Block_Address', 'City',
#        'ZIP_Code', 'ObjectId'],
#       dtype='object')

# %%
#Print Census Data column names
census_df.columns
# Out:
# Index(['ZIP_Code', 'Total_Estd_Population', 'Income_<_Poverty_level',
#        'Inc-<-PL_Male', 'Inc-<-PL_Male_Not-high-school-grad',
#        'Inc-<-PL_Male_High-school-grad',
#        'Inc-<-PL_Male_Some-college-associates',
#        'Inc-<-PL_Male_Bachelors-higher', 'Inc-<-PL_Female',
#        'Inc-<-PL_Female_Not-high-school-grad',
#        'Inc-<-PL_Female_High-school-grad',
#        'Inc-<-PL_Female_Some-college-associates',
#        'Inc-<-PL_Female_Bachelors-higher', 'Income_>=_Poverty-level',
#        'Inc->=-PL_Male', 'Inc->=-PL_Male_Not-high-school-grad',
#        'Inc->=-PL_Male_High-school-grad',
#        'Inc->=-PL_Male_Some-college-associates',
#        'Inc->=-PL_Male_Bachelors-higher', 'Inc->=-PL_Female',
#        'Inc->=-PL_Female_Not-high-school-grad',
#        'Inc->=-PL_Female_High-school-grad',
#        'Inc->=-PL_Female_Some-college-associates',
#        'Inc->=-PL_Female_Bachelors-higher'],
#       dtype='object')

# %%
# Renaming Crime Data Columns for easier access

crime_df.rename(columns={'INCIDENT_NUMBER': 'Incident_Number', 'DATE_REPORTED': 'Date_Reported', 'DATE_OCCURED': 'Date_Occurred', 'CRIME_TYPE': 'Crime_Type', 'UOR_DESC': 'UOR_Offense_Description', 'NIBRS_CODE': 'NIBRS_Code', 'UCR_HIERARCHY': 'UCR_Hierarchy', 'ATT_COMP': 'Att_Comp', 'LMPD_DIVISION': 'LMPD_Division', 'LMPD_BEAT': 'LMPD_Beat', 'PREMISE_TYPE': 'Premise_Type', 'BLOCK_ADDRESS': 'Block_Address', 'ZIP_CODE': 'ZIP_Code'}, inplace=True)
crime_df.columns
# Out:
# Index(['Incident_Number', 'Date_Reported', 'Date_Occurred', 'Crime_Type',
#        'UOR_Offense_Description', 'NIBRS_Code', 'UCR_Hierarchy', 'Att_Comp',
#        'LMPD_Division', 'LMPD_Beat', 'Premise_Type', 'Block_Address', 'City',
#        'ZIP_Code', 'ObjectId'],
#       dtype='object')

# %%
# Renaming Census Data Columns for easier access

census_df.rename(columns={'Total_Estd_Population': 'Total_Population', 'Income_<_Poverty_level': 'Income_Below_Poverty', 'Income_>=_Poverty-level': 'Income_At_Above_Poverty'}, inplace=True)
census_df.columns
# Out:
# Index(['ZIP_Code', 'Total_Population', 'Income_Below_Poverty', 'Inc-<-PL_Male',
#        'Inc-<-PL_Male_Not-high-school-grad', 'Inc-<-PL_Male_High-school-grad',
#        'Inc-<-PL_Male_Some-college-associates',
#        'Inc-<-PL_Male_Bachelors-higher', 'Inc-<-PL_Female',
#        'Inc-<-PL_Female_Not-high-school-grad',
#        'Inc-<-PL_Female_High-school-grad',
#        'Inc-<-PL_Female_Some-college-associates',
#        'Inc-<-PL_Female_Bachelors-higher', 'Income_At_Above_Poverty',
#        'Inc->=-PL_Male', 'Inc->=-PL_Male_Not-high-school-grad',
#        'Inc->=-PL_Male_High-school-grad',
#        'Inc->=-PL_Male_Some-college-associates',
#        'Inc->=-PL_Male_Bachelors-higher', 'Inc->=-PL_Female',
#        'Inc->=-PL_Female_Not-high-school-grad',
#        'Inc->=-PL_Female_High-school-grad',
#        'Inc->=-PL_Female_Some-college-associates',
#        'Inc->=-PL_Female_Bachelors-higher'],
#       dtype='object')

# %%
#Creating Socioeconomic Metrics

census_df['Poverty_Rate'] = (
    census_df['Income_Below_Poverty'] / census_df['Total_Population']
)

census_df['HS_Grad_Rate'] = (
    census_df['Inc-<-PL_Male_High-school-grad'] +
    census_df['Inc-<-PL_Male_Some-college-associates'] +
    census_df['Inc-<-PL_Male_Bachelors-higher'] +
    census_df['Inc-<-PL_Female_High-school-grad'] +
    census_df['Inc-<-PL_Female_Some-college-associates'] +
    census_df['Inc-<-PL_Female_Bachelors-higher'] + 
    census_df['Inc->=-PL_Male_High-school-grad'] +
    census_df['Inc->=-PL_Male_Some-college-associates'] +
    census_df['Inc->=-PL_Male_Bachelors-higher'] +
    census_df['Inc->=-PL_Female_High-school-grad'] +
    census_df['Inc->=-PL_Female_Some-college-associates'] +
    census_df['Inc->=-PL_Female_Bachelors-higher']
) / census_df['Total_Population'] * 100

df = census_df.drop(['Inc-<-PL_Male', 'Inc-<-PL_Male_Not-high-school-grad', 'Inc-<-PL_Male_High-school-grad', 'Inc-<-PL_Male_Some-college-associates', 'Inc-<-PL_Male_Bachelors-higher', 'Inc-<-PL_Female', 'Inc-<-PL_Female_Not-high-school-grad', 'Inc-<-PL_Female_High-school-grad', 'Inc-<-PL_Female_Some-college-associates', 'Inc-<-PL_Female_Bachelors-higher', 'Inc->=-PL_Male','Inc->=-PL_Male_Not-high-school-grad', 'Inc->=-PL_Male_High-school-grad', 'Inc->=-PL_Male_Some-college-associates', 'Inc->=-PL_Male_Bachelors-higher', 'Inc->=-PL_Female', 'Inc->=-PL_Female_Not-high-school-grad', 'Inc->=-PL_Female_High-school-grad', 'Inc->=-PL_Female_Some-college-associates', 'Inc->=-PL_Female_Bachelors-higher'], axis=1, inplace=True)

census_df
# Out:
#    ZIP_Code  Total_Population  Income_Below_Poverty  Income_At_Above_Poverty  \
# 0     40023              3692                   179                     3513
# 1     40025                83                     0                       83
# 2     40056              2269                    45                     2224
# 3     40059             14348                   194                    14154
# 4     40118              6338                   643                     5695
# 5     40177              1147                   285                      862
# 6     40202              4326                  2078                     2248
# 7     40203             11696                  3914                     7782
# 8     40204             10937                  1096                     9841
# 9     40205             17108                   934                    16174
# 10    40206             14681                  1419                    13262
# 11    40207             22317                  1210                    21107
# 12    40208              6448                  1494                     4954
# 13    40209               315                    15                      300
# 14    40210              8503                  2749                     5754
# 15    40211             13859                  3890                     9969
# 16    40212             10737                  3303                     7434
# 17    40213             11026                  1336                     9690
# 18    40214             30234                  4448                    25786
# 19    40215             12870                  3079                     9791
# 20    40216             28803                  4091                    24712
# 21    40217              9447                  1021                     8426
# 22    40218             23164                  2612                    20552
# 23    40219             26284                  2575                    23709
# 24    40220             24950                  1507                    23443
# 25    40222             16236                  1004                    15232
# 26    40223             16398                   461                    15937
# 27    40228             11360                   828                    10532
# 28    40229             27875                  2372                    25503
# 29    40231                 0                     0                        0
# 30    40241             21328                   725                    20603
# 31    40242              8183                   486                     7697
# 32    40243              7863                   398                     7465
# 33    40245             22954                  1117                    21837
# 34    40258             18017                  1510                    16507
# 35    40272             25992                  2555                    23437
# 36    40280               189                    47                      142
# 37    40291             26911                  1304                    25607
# 38    40299             29437                  1137                    28300
#
#     Poverty_Rate  HS_Grad_Rate
# 0       0.048483     95.855905
# 1       0.000000    100.000000
# 2       0.019833     96.826796
# 3       0.013521     98.390020
# 4       0.101452     81.492584
# 5       0.248474     81.691369
# 6       0.480351     88.210818
# 7       0.334644     85.995212
# 8       0.100210     95.839810
# 9       0.054594     97.001403
# 10      0.096656     93.890062
# 11      0.054219     97.831250
# 12      0.231700     86.243797
# 13      0.047619     58.095238
# 14      0.323298     80.501000
# 15      0.280684     80.337687
# 16      0.307628     79.715004
# 17      0.121168     88.227825
# 18      0.147119     85.046636
# 19      0.239239     79.153069
# 20      0.142034     85.501510
# 21      0.108077     93.775802
# 22      0.112761     89.449145
# 23      0.097968     87.030132
# 24      0.060401     95.987976
# 25      0.061838     96.760286
# 26      0.028113     96.627638
# 27      0.072887     93.186620
# 28      0.085094     90.242152
# 29           NaN           NaN
# 30      0.033993     96.656977
# 31      0.059391     93.926433
# 32      0.050617     97.329264
# 33      0.048663     96.954779
# 34      0.083810     88.927124
# 35      0.098299     87.172976
# 36      0.248677    100.000000
# 37      0.048456     95.213853
# 38      0.038625     95.271257

# %%
# Indentifying missing value fields in Crime Data as counts and as a percentage of the total dataset for each column

def missing_values(df):
    df = df.copy()

    missing_count = df.isnull().sum()
    missing_percent = missing_count * 100 / len(df)

    return pd.DataFrame({
        'Missing_Count': missing_count,
        'Missing_Percentage': missing_percent

    })

missing_data_df = missing_values(crime_df)
missing_data_df
# Out:
#                          Missing_Count  Missing_Percentage
# Incident_Number                      0            0.000000
# Date_Reported                        0            0.000000
# Date_Occurred                        0            0.000000
# Crime_Type                           0            0.000000
# UOR_Offense_Description              0            0.000000
# NIBRS_Code                           0            0.000000
# UCR_Hierarchy                     1770            2.520183
# Att_Comp                            61            0.086854
# LMPD_Division                        0            0.000000
# LMPD_Beat                            2            0.002848
# Premise_Type                         8            0.011391
# Block_Address                        0            0.000000
# City                                11            0.015662
# ZIP_Code                            46            0.065496
# ObjectId                             0            0.000000

# %%
# Identifying data types of each Crime Data column
crime_df.dtypes
# Out:
# Incident_Number                    object
# Date_Reported              datetime64[ns]
# Date_Occurred              datetime64[ns]
# Crime_Type                         object
# UOR_Offense_Description            object
# NIBRS_Code                         object
# UCR_Hierarchy                      object
# Att_Comp                           object
# LMPD_Division                      object
# LMPD_Beat                          object
# Premise_Type                       object
# Block_Address                      object
# City                               object
# ZIP_Code                           object
# ObjectId                            int64
# dtype: object

# %%
# Converting 'Date_Reported' and 'Date_Occurred' fields to datetime format in Crime Data

crime_df['Date_Reported'] = pd.to_datetime(
    crime_df['Date_Reported'],
    errors='coerce'
)

crime_df['Date_Occurred'] = pd.to_datetime(
    crime_df['Date_Occurred'],
    errors='coerce'
)
crime_df.dtypes
# Out:
# Incident_Number                    object
# Date_Reported              datetime64[ns]
# Date_Occurred              datetime64[ns]
# Crime_Type                         object
# UOR_Offense_Description            object
# NIBRS_Code                         object
# UCR_Hierarchy                      object
# Att_Comp                           object
# LMPD_Division                      object
# LMPD_Beat                          object
# Premise_Type                       object
# Block_Address                      object
# City                               object
# ZIP_Code                           object
# ObjectId                            int64
# dtype: object

# %% [markdown]
# Parsing the year/month/date/time/day of week from the 2 date fields in Crime Data and moving the new fields to come after their source columns

# %%
# Creating new fields for year, month, day, time, and day of week for both 'Date_Reported' and 'Date_Occurred' in Crime Data for easier analysis of temporal patterns in crime incidents and reordering columns to place these new fields next to the original date fields for easier access and analysis


def date_fields(df):
    
    df = df.copy()

    df['reported_year'] = df['Date_Reported'].dt.year
    df['reported_month'] = df['Date_Reported'].dt.month
    df['reported_day'] = df['Date_Reported'].dt.day
    df['reported_time'] = df['Date_Reported'].dt.time
    df['reported_dow'] = df['Date_Reported'].dt.day_name()

    df['occurred_year'] = df['Date_Occurred'].dt.year
    df['occurred_month'] = df['Date_Occurred'].dt.month
    df['occurred_day'] = df['Date_Occurred'].dt.day
    df['occurred_time'] = df['Date_Occurred'].dt.time
    df['occurred_dow'] = df['Date_Occurred'].dt.day_name()
    
    cols_to_move = ['Date_Reported', 'reported_year', 'reported_month', 'reported_day', 'reported_time', 'reported_dow', 'Date_Occurred', 'occurred_year', 'occurred_month', 'occurred_day', 'occurred_time', 'occurred_dow']

    cols = list(df.columns)

    for col in cols_to_move:
        cols.remove(col)

    insert_at = 3
    for i, col in enumerate(cols_to_move):
        cols.insert(insert_at + i, col)

    df = df[cols]
    
    
# Reordering Crime Data columns to place 'Crime_Type' and 'UOR_Offense_Description' next to other crime classification data for easier analysis

    cols_to_move = ['Crime_Type', 'UOR_Offense_Description']

    cols = list(df.columns)

    for col in cols_to_move:
        cols.remove(col)

    insert_at = 13
    for i, col in enumerate(cols_to_move):
        cols.insert(insert_at + i, col)

    df = df[cols]
    
    return df

split_data_df = date_fields(crime_df)
split_data_df
# Out:
#       Incident_Number       Date_Reported  reported_year  reported_month  \
# 0        80-20-000117 2020-01-01 13:50:00           2020               1
# 1        80-20-000292 2020-01-02 10:45:00           2020               1
# 2        80-19-096135 2020-01-01 00:26:00           2020               1
# 3        80-20-000234 2020-01-01 23:57:00           2020               1
# 4        80-20-000294 2020-01-02 11:02:00           2020               1
# ...               ...                 ...            ...             ...
# 70228    80-20-077551 2020-12-31 16:09:00           2020              12
# 70229    80-20-077552 2020-12-31 15:38:00           2020              12
# 70230    80-20-077554 2020-12-31 16:25:00           2020              12
# 70231    80-20-077553 2020-12-31 15:39:00           2020              12
# 70232    80-20-077555 2020-12-31 16:26:00           2020              12
#
#        reported_day reported_time reported_dow       Date_Occurred  \
# 0                 1      13:50:00    Wednesday 2019-12-31 03:30:00
# 1                 2      10:45:00     Thursday 2019-12-31 18:00:00
# 2                 1      00:26:00    Wednesday 2019-12-31 23:30:00
# 3                 1      23:57:00    Wednesday 2020-01-01 03:00:00
# 4                 2      11:02:00     Thursday 2019-12-31 12:00:00
# ...             ...           ...          ...                 ...
# 70228            31      16:09:00     Thursday 2020-12-31 15:00:00
# 70229            31      15:38:00     Thursday 2020-12-31 14:25:00
# 70230            31      16:25:00     Thursday 2020-12-31 00:01:00
# 70231            31      15:39:00     Thursday 2020-12-31 15:34:00
# 70232            31      16:26:00     Thursday 2020-12-30 20:30:00
#
#        occurred_year  occurred_month  ...  NIBRS_Code UCR_Hierarchy  \
# 0               2019              12  ...         26B       PART II
# 1               2019              12  ...         23H        PART I
# 2               2019              12  ...         23F        PART I
# 3               2020               1  ...         290       PART II
# 4               2019              12  ...         23F        PART I
# ...              ...             ...  ...         ...           ...
# 70228           2020              12  ...         23F        PART I
# 70229           2020              12  ...         13B       PART II
# 70230           2020              12  ...         23F        PART I
# 70231           2020              12  ...         13B       PART II
# 70232           2020              12  ...         23F        PART I
#
#         Att_Comp LMPD_Division LMPD_Beat  \
# 0      COMPLETED  4TH DIVISION       435
# 1      COMPLETED  6TH DIVISION       613
# 2      COMPLETED  1ST DIVISION       112
# 3      COMPLETED  4TH DIVISION       424
# 4      COMPLETED  7TH DIVISION       736
# ...          ...           ...       ...
# 70228  COMPLETED  5TH DIVISION       525
# 70229  COMPLETED  2ND DIVISION       225
# 70230  COMPLETED  7TH DIVISION       723
# 70231  COMPLETED  3RD DIVISION       331
# 70232  COMPLETED  8TH DIVISION       824
#
#                                         Premise_Type  \
# 0      SERVICE / GAS STATION
# 1      NON-ATTACHED RESD GARAGE/SHED/BULD
# 2      HIGHWAY / ROAD / ALLEY
# 3      HIGHWAY / ROAD / ALLEY
# 4      DOCK/WHARF/FREIGHT/MODAL TERMINAL
# ...                                              ...
# 70228  PARKING LOT / GARAGE
# 70229  OTHER / UNKNOWN
# 70230  RESIDENCE / HOME
# 70231  RESIDENCE / HOME
# 70232  RESIDENCE / HOME
#
#                                            Block_Address        City ZIP_Code  \
# 0      4100 BLOCK TAYLOR BLVD                        ...  LOUISVILLE    40215
# 1      5200 BLOCK RUSSETT BLVD                       ...  LOUISVILLE    40218
# 2      S 16TH ST / W CHESTNUT ST                     ...  LOUISVILLE    40203
# 3      2700 BLOCK S 4TH ST                           ...  LOUISVILLE    40208
# 4      1800 BLOCK SOUTH PARK RD                      ...  LOUISVILLE    40219
# ...                                                  ...         ...      ...
# 70228  700 BLOCK COCHRAN HILL RD                     ...  LOUISVILLE  40206.0
# 70229  1600 BLOCK MOORE CT                           ...  LOUISVILLE  40210.0
# 70230  7600 BLOCK AVALON GARDEN DR                   ...  LOUISVILLE  40228.0
# 70231  3300 BLOCK RENWOOD BLVD                       ...  LOUISVILLE  40214.0
# 70232  12600 BLOCK OLD HENRY RD                      ...  LOUISVILLE  40223.0
#
#       ObjectId
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
# ...        ...
# 70228    70229
# 70229    70230
# 70230    70231
# 70231    70232
# 70232    70233
#
# [70233 rows x 25 columns]

# %%
# Rediscovering data types after adding new columns

split_data_df.dtypes
# Out:
# Incident_Number                    object
# Date_Reported              datetime64[ns]
# reported_year                       int32
# reported_month                      int32
# reported_day                        int32
# reported_time                      object
# reported_dow                       object
# Date_Occurred              datetime64[ns]
# occurred_year                       int32
# occurred_month                      int32
# occurred_day                        int32
# occurred_time                      object
# occurred_dow                       object
# Crime_Type                         object
# UOR_Offense_Description            object
# NIBRS_Code                         object
# UCR_Hierarchy                      object
# Att_Comp                           object
# LMPD_Division                      object
# LMPD_Beat                          object
# Premise_Type                       object
# Block_Address                      object
# City                               object
# ZIP_Code                           object
# ObjectId                            int64
# dtype: object

# %% [markdown]
# Data cleansing (EDA)

# %%
# Cleaning 'ZIP_Code' and 'City' fields in Crime Data to standardize and prepare for analysis, including handling missing values, correcting known data entry errors, and validating against expected Louisville ZIP Codes (40xxx). This process may involve multiple steps such as normalization, imputation, and validation to ensure the integrity of the data for subsequent analysis.


def clean_zip_codes(df):
    """
    Cleans and standardizes ZIP_Code field in the crime dataset.
    
    Steps:
    - Normalize format
    - Remove/replace invalid values
    - Impute missing ZIPs using Block_Address and/or LMPD_Beat
    - Validate Louisville ZIPs (40xxx)
    
    Returns cleaned DataFrame.
    """
    
    df = df.copy()
    
    # 1. Normalize format (remove floating point artifacts and convert to string)
    df['ZIP_Code'] = (
        df['ZIP_Code']
        .astype(str)
        .str.replace(r'\.0$', '', regex=True)
    )
    
    # 2. Replace known invalid values with valid values, including replacing 40056 with 40231, which is a valid Louisville ZIP Code and is included in Census Data, and correcting 'DRIVE' and '4291' to valid ZIP Codes based on common data entry errors observed in the dataset.
    df['ZIP_Code'] = (
        df['ZIP_Code']
        .replace('40056', '40231')
        .replace('DRIVE', '40219')
        .replace('4291', '40291')
    )

    # 3. Replace known blank values with NA
    df['ZIP_Code'] = (
        df['ZIP_Code']
        .replace(['00000', '', 'nan', 'NaN', 'None', '<NA>'], pd.NA)
    )
    
    # 4. Replace blank ZIP_Code fields with the most common ZIP_Code for that LMPD_Beat, which may help retain more records in the analysis while acknowledging the limitations of the data. However, this method may not be accurate for all records, as it assumes that the most common ZIP_Code for a given LMPD_Beat is representative of all crimes that occurred in that beat, which may not always be the case.
    df['ZIP_Code'] = (
        df.groupby('LMPD_Beat')['ZIP_Code']
        .transform(lambda x: x.fillna(x.mode().iloc[0]) if not x.mode().empty else x)
    )
    
    # 5. Create lookup from most common ZIP for Block_Address
    zip_lookup = (
        df.groupby('Block_Address')['ZIP_Code']
        .agg(lambda x: x.mode().iloc[0] if not x.mode().empty else pd.NA)
    )

    # 6. Fill any additional missing ZIPs using Block_Address
    df['ZIP_Code'] = df.apply(
        lambda row: zip_lookup[row['Block_Address']]
        if pd.isna(row['ZIP_Code']) else row['ZIP_Code'],
        axis=1
    )

    # 7. Standardize City names
    df['City'] = (
        df['City']
        .replace('1719', 'HOLLYVILLA')
        .replace('LOUISV', 'LOUISVILLE')
        .replace('LOUUSVILLE', 'LOUISVILLE')
        .replace('', pd.NA)
        .fillna('LOUISVILLE')
    )

    # 8. Optional fallback (Louisville default ZIP and City)
    df.loc[
        df['Block_Address'].str.upper().str.strip().eq('COMMUNITY AT LARGE')
        & df['ZIP_Code'].isna(),
        'ZIP_Code'
    ] = '40231'

    df.loc[
        (df['City'] == 'LOUISVILLE') & (df['ZIP_Code'].isna()),
        'ZIP_Code'
    ] = '40231'

    # 9. Final validation (keep only Louisville ZIPs)
    df = df[
        df['ZIP_Code'].str.match(r'^40\d{3}$', na=False)
    ]

    return df

cleaned_df = clean_zip_codes(split_data_df)

cleaned_df
# Out:
#       Incident_Number       Date_Reported  reported_year  reported_month  \
# 0        80-20-000117 2020-01-01 13:50:00           2020               1
# 1        80-20-000292 2020-01-02 10:45:00           2020               1
# 2        80-19-096135 2020-01-01 00:26:00           2020               1
# 3        80-20-000234 2020-01-01 23:57:00           2020               1
# 4        80-20-000294 2020-01-02 11:02:00           2020               1
# ...               ...                 ...            ...             ...
# 70228    80-20-077551 2020-12-31 16:09:00           2020              12
# 70229    80-20-077552 2020-12-31 15:38:00           2020              12
# 70230    80-20-077554 2020-12-31 16:25:00           2020              12
# 70231    80-20-077553 2020-12-31 15:39:00           2020              12
# 70232    80-20-077555 2020-12-31 16:26:00           2020              12
#
#        reported_day reported_time reported_dow       Date_Occurred  \
# 0                 1      13:50:00    Wednesday 2019-12-31 03:30:00
# 1                 2      10:45:00     Thursday 2019-12-31 18:00:00
# 2                 1      00:26:00    Wednesday 2019-12-31 23:30:00
# 3                 1      23:57:00    Wednesday 2020-01-01 03:00:00
# 4                 2      11:02:00     Thursday 2019-12-31 12:00:00
# ...             ...           ...          ...                 ...
# 70228            31      16:09:00     Thursday 2020-12-31 15:00:00
# 70229            31      15:38:00     Thursday 2020-12-31 14:25:00
# 70230            31      16:25:00     Thursday 2020-12-31 00:01:00
# 70231            31      15:39:00     Thursday 2020-12-31 15:34:00
# 70232            31      16:26:00     Thursday 2020-12-30 20:30:00
#
#        occurred_year  occurred_month  ...  NIBRS_Code UCR_Hierarchy  \
# 0               2019              12  ...         26B       PART II
# 1               2019              12  ...         23H        PART I
# 2               2019              12  ...         23F        PART I
# 3               2020               1  ...         290       PART II
# 4               2019              12  ...         23F        PART I
# ...              ...             ...  ...         ...           ...
# 70228           2020              12  ...         23F        PART I
# 70229           2020              12  ...         13B       PART II
# 70230           2020              12  ...         23F        PART I
# 70231           2020              12  ...         13B       PART II
# 70232           2020              12  ...         23F        PART I
#
#         Att_Comp LMPD_Division LMPD_Beat  \
# 0      COMPLETED  4TH DIVISION       435
# 1      COMPLETED  6TH DIVISION       613
# 2      COMPLETED  1ST DIVISION       112
# 3      COMPLETED  4TH DIVISION       424
# 4      COMPLETED  7TH DIVISION       736
# ...          ...           ...       ...
# 70228  COMPLETED  5TH DIVISION       525
# 70229  COMPLETED  2ND DIVISION       225
# 70230  COMPLETED  7TH DIVISION       723
# 70231  COMPLETED  3RD DIVISION       331
# 70232  COMPLETED  8TH DIVISION       824
#
#                                         Premise_Type  \
# 0      SERVICE / GAS STATION
# 1      NON-ATTACHED RESD GARAGE/SHED/BULD
# 2      HIGHWAY / ROAD / ALLEY
# 3      HIGHWAY / ROAD / ALLEY
# 4      DOCK/WHARF/FREIGHT/MODAL TERMINAL
# ...                                              ...
# 70228  PARKING LOT / GARAGE
# 70229  OTHER / UNKNOWN
# 70230  RESIDENCE / HOME
# 70231  RESIDENCE / HOME
# 70232  RESIDENCE / HOME
#
#                                            Block_Address        City ZIP_Code  \
# 0      4100 BLOCK TAYLOR BLVD                        ...  LOUISVILLE    40215
# 1      5200 BLOCK RUSSETT BLVD                       ...  LOUISVILLE    40218
# 2      S 16TH ST / W CHESTNUT ST                     ...  LOUISVILLE    40203
# 3      2700 BLOCK S 4TH ST                           ...  LOUISVILLE    40208
# 4      1800 BLOCK SOUTH PARK RD                      ...  LOUISVILLE    40219
# ...                                                  ...         ...      ...
# 70228  700 BLOCK COCHRAN HILL RD                     ...  LOUISVILLE    40206
# 70229  1600 BLOCK MOORE CT                           ...  LOUISVILLE    40210
# 70230  7600 BLOCK AVALON GARDEN DR                   ...  LOUISVILLE    40228
# 70231  3300 BLOCK RENWOOD BLVD                       ...  LOUISVILLE    40214
# 70232  12600 BLOCK OLD HENRY RD                      ...  LOUISVILLE    40223
#
#       ObjectId
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
# ...        ...
# 70228    70229
# 70229    70230
# 70230    70231
# 70231    70232
# 70232    70233
#
# [70232 rows x 25 columns]

# %%
# Cleaning data fields function

def clean_data_fields(df):
    """
    Cleans and standardizes several fields in the crime dataset.
    
    Steps:
    - Fill in blank Attempted/Completed column values with "Unknown"
    - Fill in blank Premise_Type column values with "Unknown"
    - Fill in invalid/blank UCR_Hierarchy column values with "NA"
    - Replace "NA" UCR_Hierarchy column values with "Unknown"
    
    Returns cleaned DataFrame.
    """
    
    df = df.copy()

# 1. Fill in blank Attempted/Completed column values with "Unknown"

    df['Att_Comp'] = (
        df['Att_Comp']
        .replace('', pd.NA)
        .fillna('UNKNOWN')
    )
    
# 2. Fill in blank Premise_Type column values with "Unknown"
    df['Premise_Type'] = (
        df['Premise_Type']
        .replace('', pd.NA)
        .fillna('UNKNOWN')
    )

# 3. Fill in invalid/blank UCR_Hierarchy column values with "NA"
    df['UCR_Hierarchy'] = (
        df['UCR_Hierarchy']
        .replace(['', 'nan', 'NaN', None], pd.NA)
)

# 4. Replace "NA" UCR_Hierarchy column values with "Unknown"
    df['UCR_Hierarchy'] = (
        df['UCR_Hierarchy']
        .fillna('UNKNOWN')
    )

    return df

cleaned2_df = clean_data_fields(cleaned_df)    

cleaned2_df
# Out:
#       Incident_Number       Date_Reported  reported_year  reported_month  \
# 0        80-20-000117 2020-01-01 13:50:00           2020               1
# 1        80-20-000292 2020-01-02 10:45:00           2020               1
# 2        80-19-096135 2020-01-01 00:26:00           2020               1
# 3        80-20-000234 2020-01-01 23:57:00           2020               1
# 4        80-20-000294 2020-01-02 11:02:00           2020               1
# ...               ...                 ...            ...             ...
# 70228    80-20-077551 2020-12-31 16:09:00           2020              12
# 70229    80-20-077552 2020-12-31 15:38:00           2020              12
# 70230    80-20-077554 2020-12-31 16:25:00           2020              12
# 70231    80-20-077553 2020-12-31 15:39:00           2020              12
# 70232    80-20-077555 2020-12-31 16:26:00           2020              12
#
#        reported_day reported_time reported_dow       Date_Occurred  \
# 0                 1      13:50:00    Wednesday 2019-12-31 03:30:00
# 1                 2      10:45:00     Thursday 2019-12-31 18:00:00
# 2                 1      00:26:00    Wednesday 2019-12-31 23:30:00
# 3                 1      23:57:00    Wednesday 2020-01-01 03:00:00
# 4                 2      11:02:00     Thursday 2019-12-31 12:00:00
# ...             ...           ...          ...                 ...
# 70228            31      16:09:00     Thursday 2020-12-31 15:00:00
# 70229            31      15:38:00     Thursday 2020-12-31 14:25:00
# 70230            31      16:25:00     Thursday 2020-12-31 00:01:00
# 70231            31      15:39:00     Thursday 2020-12-31 15:34:00
# 70232            31      16:26:00     Thursday 2020-12-30 20:30:00
#
#        occurred_year  occurred_month  ...  NIBRS_Code UCR_Hierarchy  \
# 0               2019              12  ...         26B       PART II
# 1               2019              12  ...         23H        PART I
# 2               2019              12  ...         23F        PART I
# 3               2020               1  ...         290       PART II
# 4               2019              12  ...         23F        PART I
# ...              ...             ...  ...         ...           ...
# 70228           2020              12  ...         23F        PART I
# 70229           2020              12  ...         13B       PART II
# 70230           2020              12  ...         23F        PART I
# 70231           2020              12  ...         13B       PART II
# 70232           2020              12  ...         23F        PART I
#
#         Att_Comp LMPD_Division LMPD_Beat  \
# 0      COMPLETED  4TH DIVISION       435
# 1      COMPLETED  6TH DIVISION       613
# 2      COMPLETED  1ST DIVISION       112
# 3      COMPLETED  4TH DIVISION       424
# 4      COMPLETED  7TH DIVISION       736
# ...          ...           ...       ...
# 70228  COMPLETED  5TH DIVISION       525
# 70229  COMPLETED  2ND DIVISION       225
# 70230  COMPLETED  7TH DIVISION       723
# 70231  COMPLETED  3RD DIVISION       331
# 70232  COMPLETED  8TH DIVISION       824
#
#                                         Premise_Type  \
# 0      SERVICE / GAS STATION
# 1      NON-ATTACHED RESD GARAGE/SHED/BULD
# 2      HIGHWAY / ROAD / ALLEY
# 3      HIGHWAY / ROAD / ALLEY
# 4      DOCK/WHARF/FREIGHT/MODAL TERMINAL
# ...                                              ...
# 70228  PARKING LOT / GARAGE
# 70229  OTHER / UNKNOWN
# 70230  RESIDENCE / HOME
# 70231  RESIDENCE / HOME
# 70232  RESIDENCE / HOME
#
#                                            Block_Address        City ZIP_Code  \
# 0      4100 BLOCK TAYLOR BLVD                        ...  LOUISVILLE    40215
# 1      5200 BLOCK RUSSETT BLVD                       ...  LOUISVILLE    40218
# 2      S 16TH ST / W CHESTNUT ST                     ...  LOUISVILLE    40203
# 3      2700 BLOCK S 4TH ST                           ...  LOUISVILLE    40208
# 4      1800 BLOCK SOUTH PARK RD                      ...  LOUISVILLE    40219
# ...                                                  ...         ...      ...
# 70228  700 BLOCK COCHRAN HILL RD                     ...  LOUISVILLE    40206
# 70229  1600 BLOCK MOORE CT                           ...  LOUISVILLE    40210
# 70230  7600 BLOCK AVALON GARDEN DR                   ...  LOUISVILLE    40228
# 70231  3300 BLOCK RENWOOD BLVD                       ...  LOUISVILLE    40214
# 70232  12600 BLOCK OLD HENRY RD                      ...  LOUISVILLE    40223
#
#       ObjectId
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
# ...        ...
# 70228    70229
# 70229    70230
# 70230    70231
# 70231    70232
# 70232    70233
#
# [70232 rows x 25 columns]

# %%
# Classifying Crime Types: Crime categories were derived using offense descriptions and mapped into violent and property classifications using keyword-based rules aligned with standard criminology definitions. I included all known violent crime types in the keywords list, but this may not be exhaustive and may require further refinement based on the specific crime types present in the dataset and their classifications. Additionally, the classification is based on the presence of keywords in the crime description, which may not always accurately reflect the nature of the crime, so further validation may be necessary to ensure accurate categorization. Much of the "OTHER" category appear to be violent crimes that are not explicitly labeled as such in the dataset, so further analysis may be needed to identify and classify these incidents appropriately.

violent_keywords = [
    "HOMICIDE",
    "ASSAULT",
    "ROBBERY",
    "SEX CRIMES",
    "WEAPONS",
    "ARSON",
    "OTHER"
]

def classify_crime(description):
    if isinstance(description, str):
        desc = description.upper()
        if any(word in desc for word in violent_keywords):
            return "Violent"
    return "Property"

cleaned2_df['Crime_Category'] = cleaned2_df['Crime_Type'].apply(classify_crime)

cleaned2_df
# Out:
#       Incident_Number       Date_Reported  reported_year  reported_month  \
# 0        80-20-000117 2020-01-01 13:50:00           2020               1
# 1        80-20-000292 2020-01-02 10:45:00           2020               1
# 2        80-19-096135 2020-01-01 00:26:00           2020               1
# 3        80-20-000234 2020-01-01 23:57:00           2020               1
# 4        80-20-000294 2020-01-02 11:02:00           2020               1
# ...               ...                 ...            ...             ...
# 70228    80-20-077551 2020-12-31 16:09:00           2020              12
# 70229    80-20-077552 2020-12-31 15:38:00           2020              12
# 70230    80-20-077554 2020-12-31 16:25:00           2020              12
# 70231    80-20-077553 2020-12-31 15:39:00           2020              12
# 70232    80-20-077555 2020-12-31 16:26:00           2020              12
#
#        reported_day reported_time reported_dow       Date_Occurred  \
# 0                 1      13:50:00    Wednesday 2019-12-31 03:30:00
# 1                 2      10:45:00     Thursday 2019-12-31 18:00:00
# 2                 1      00:26:00    Wednesday 2019-12-31 23:30:00
# 3                 1      23:57:00    Wednesday 2020-01-01 03:00:00
# 4                 2      11:02:00     Thursday 2019-12-31 12:00:00
# ...             ...           ...          ...                 ...
# 70228            31      16:09:00     Thursday 2020-12-31 15:00:00
# 70229            31      15:38:00     Thursday 2020-12-31 14:25:00
# 70230            31      16:25:00     Thursday 2020-12-31 00:01:00
# 70231            31      15:39:00     Thursday 2020-12-31 15:34:00
# 70232            31      16:26:00     Thursday 2020-12-30 20:30:00
#
#        occurred_year  occurred_month  ...  UCR_Hierarchy   Att_Comp  \
# 0               2019              12  ...        PART II  COMPLETED
# 1               2019              12  ...         PART I  COMPLETED
# 2               2019              12  ...         PART I  COMPLETED
# 3               2020               1  ...        PART II  COMPLETED
# 4               2019              12  ...         PART I  COMPLETED
# ...              ...             ...  ...            ...        ...
# 70228           2020              12  ...         PART I  COMPLETED
# 70229           2020              12  ...        PART II  COMPLETED
# 70230           2020              12  ...         PART I  COMPLETED
# 70231           2020              12  ...        PART II  COMPLETED
# 70232           2020              12  ...         PART I  COMPLETED
#
#       LMPD_Division LMPD_Beat                                   Premise_Type  \
# 0      4TH DIVISION       435  SERVICE / GAS STATION
# 1      6TH DIVISION       613  NON-ATTACHED RESD GARAGE/SHED/BULD
# 2      1ST DIVISION       112  HIGHWAY / ROAD / ALLEY
# 3      4TH DIVISION       424  HIGHWAY / ROAD / ALLEY
# 4      7TH DIVISION       736  DOCK/WHARF/FREIGHT/MODAL TERMINAL
# ...             ...       ...                                            ...
# 70228  5TH DIVISION       525  PARKING LOT / GARAGE
# 70229  2ND DIVISION       225  OTHER / UNKNOWN
# 70230  7TH DIVISION       723  RESIDENCE / HOME
# 70231  3RD DIVISION       331  RESIDENCE / HOME
# 70232  8TH DIVISION       824  RESIDENCE / HOME
#
#                                            Block_Address        City ZIP_Code  \
# 0      4100 BLOCK TAYLOR BLVD                        ...  LOUISVILLE    40215
# 1      5200 BLOCK RUSSETT BLVD                       ...  LOUISVILLE    40218
# 2      S 16TH ST / W CHESTNUT ST                     ...  LOUISVILLE    40203
# 3      2700 BLOCK S 4TH ST                           ...  LOUISVILLE    40208
# 4      1800 BLOCK SOUTH PARK RD                      ...  LOUISVILLE    40219
# ...                                                  ...         ...      ...
# 70228  700 BLOCK COCHRAN HILL RD                     ...  LOUISVILLE    40206
# 70229  1600 BLOCK MOORE CT                           ...  LOUISVILLE    40210
# 70230  7600 BLOCK AVALON GARDEN DR                   ...  LOUISVILLE    40228
# 70231  3300 BLOCK RENWOOD BLVD                       ...  LOUISVILLE    40214
# 70232  12600 BLOCK OLD HENRY RD                      ...  LOUISVILLE    40223
#
#       ObjectId Crime_Category
# 0            1       Property
# 1            2       Property
# 2            3       Property
# 3            4       Property
# 4            5       Property
# ...        ...            ...
# 70228    70229       Property
# 70229    70230        Violent
# 70230    70231       Property
# 70231    70232        Violent
# 70232    70233       Property
#
# [70232 rows x 26 columns]

# %%
#Aggregating Crime Data by ZIP Code to prepare for merging with Census Data and analysis of crime patterns in relation to socioeconomic conditions across different areas of Louisville. This process involves grouping the crime incidents by ZIP Code and calculating relevant metrics such as total crime counts, violent crime counts, property crime counts, and crime rates per capita, which can then be compared against socioeconomic indicators from the Census Data to identify potential correlations and insights.

crime_summary = cleaned2_df.groupby('ZIP_Code').agg(
    Total_Crimes=('Incident_Number', 'count'),
    Violent_Crimes=('Crime_Category', lambda x: (x == 'Violent').sum()),
    Property_Crimes=('Crime_Category', lambda x: (x == 'Property').sum())
).reset_index()

crime_summary
# Out:
#    ZIP_Code  Total_Crimes  Violent_Crimes  Property_Crimes
# 0     40023            50              11               39
# 1     40025             2               0                2
# 2     40059           193              52              141
# 3     40118           859             368              491
# 4     40177            18               6               12
# 5     40202          2888            1118             1770
# 6     40203          4459            1993             2466
# 7     40204          1806             513             1293
# 8     40205          1143             319              824
# 9     40206          1931             678             1253
# 10    40207           515             165              350
# 11    40208          3006            1150             1856
# 12    40209           530             143              387
# 13    40210          3351            1815             1536
# 14    40211          4807            2372             2435
# 15    40212          3924            1895             2029
# 16    40213          2290             695             1595
# 17    40214          5189            2086             3103
# 18    40215          4171            1890             2281
# 19    40216          3216            1287             1929
# 20    40217          1293             440              853
# 21    40218          2713            1196             1517
# 22    40219          4373            1392             2981
# 23    40220          1522             578              944
# 24    40222          1105             271              834
# 25    40223           698             204              494
# 26    40225            34              11               23
# 27    40228           923             308              615
# 28    40229          1762             644             1118
# 29    40231           233             212               21
# 30    40241          1369             389              980
# 31    40242           325             121              204
# 32    40243           299              62              237
# 33    40245           934             303              631
# 34    40258          2492             880             1612
# 35    40272          3210            1228             1982
# 36    40291          1640             581             1059
# 37    40299           959             266              693

# %%
# Merging Crime Summary with Census Data to analyze crime patterns in relation to socioeconomic conditions across different areas of Louisville. This process involves combining the aggregated crime data by ZIP Code with the corresponding socioeconomic indicators from the Census Data, such as total population and poverty rate, to enable a comprehensive analysis of how crime rates may correlate with socioeconomic factors in different neighborhoods of Louisville.

merged = crime_summary.merge(
    census_df,
    on='ZIP_Code',
    how='inner'
)

merged['Crime_Rate'] = (merged['Total_Crimes'] / merged['Total_Population']) * 1000
merged['Violent_Rate'] = (merged['Violent_Crimes'] / merged['Total_Population']) * 1000
merged['Property_Rate'] = (merged['Property_Crimes'] / merged['Total_Population']) * 1000

merged = merged.dropna(subset=['Poverty_Rate', 'Crime_Rate'])

merged['Poverty_Group'] = pd.cut(
    merged['Poverty_Rate'],
    bins=[0, 0.1, 0.2, 0.3, 1.0],
    labels=['Low Poverty', 'Moderate', 'High', 'Very High'],
    include_lowest=True
)

merged
# Out:
#    ZIP_Code  Total_Crimes  Violent_Crimes  Property_Crimes  Total_Population  \
# 0     40023            50              11               39              3692
# 1     40025             2               0                2                83
# 2     40059           193              52              141             14348
# 3     40118           859             368              491              6338
# 4     40177            18               6               12              1147
# 5     40202          2888            1118             1770              4326
# 6     40203          4459            1993             2466             11696
# 7     40204          1806             513             1293             10937
# 8     40205          1143             319              824             17108
# 9     40206          1931             678             1253             14681
# 10    40207           515             165              350             22317
# 11    40208          3006            1150             1856              6448
# 12    40209           530             143              387               315
# 13    40210          3351            1815             1536              8503
# 14    40211          4807            2372             2435             13859
# 15    40212          3924            1895             2029             10737
# 16    40213          2290             695             1595             11026
# 17    40214          5189            2086             3103             30234
# 18    40215          4171            1890             2281             12870
# 19    40216          3216            1287             1929             28803
# 20    40217          1293             440              853              9447
# 21    40218          2713            1196             1517             23164
# 22    40219          4373            1392             2981             26284
# 23    40220          1522             578              944             24950
# 24    40222          1105             271              834             16236
# 25    40223           698             204              494             16398
# 26    40228           923             308              615             11360
# 27    40229          1762             644             1118             27875
# 29    40241          1369             389              980             21328
# 30    40242           325             121              204              8183
# 31    40243           299              62              237              7863
# 32    40245           934             303              631             22954
# 33    40258          2492             880             1612             18017
# 34    40272          3210            1228             1982             25992
# 35    40291          1640             581             1059             26911
# 36    40299           959             266              693             29437
#
#     Income_Below_Poverty  Income_At_Above_Poverty  Poverty_Rate  HS_Grad_Rate  \
# 0                    179                     3513      0.048483     95.855905
# 1                      0                       83      0.000000    100.000000
# 2                    194                    14154      0.013521     98.390020
# 3                    643                     5695      0.101452     81.492584
# 4                    285                      862      0.248474     81.691369
# 5                   2078                     2248      0.480351     88.210818
# 6                   3914                     7782      0.334644     85.995212
# 7                   1096                     9841      0.100210     95.839810
# 8                    934                    16174      0.054594     97.001403
# 9                   1419                    13262      0.096656     93.890062
# 10                  1210                    21107      0.054219     97.831250
# 11                  1494                     4954      0.231700     86.243797
# 12                    15                      300      0.047619     58.095238
# 13                  2749                     5754      0.323298     80.501000
# 14                  3890                     9969      0.280684     80.337687
# 15                  3303                     7434      0.307628     79.715004
# 16                  1336                     9690      0.121168     88.227825
# 17                  4448                    25786      0.147119     85.046636
# 18                  3079                     9791      0.239239     79.153069
# 19                  4091                    24712      0.142034     85.501510
# 20                  1021                     8426      0.108077     93.775802
# 21                  2612                    20552      0.112761     89.449145
# 22                  2575                    23709      0.097968     87.030132
# 23                  1507                    23443      0.060401     95.987976
# 24                  1004                    15232      0.061838     96.760286
# 25                   461                    15937      0.028113     96.627638
# 26                   828                    10532      0.072887     93.186620
# 27                  2372                    25503      0.085094     90.242152
# 29                   725                    20603      0.033993     96.656977
# 30                   486                     7697      0.059391     93.926433
# 31                   398                     7465      0.050617     97.329264
# 32                  1117                    21837      0.048663     96.954779
# 33                  1510                    16507      0.083810     88.927124
# 34                  2555                    23437      0.098299     87.172976
# 35                  1304                    25607      0.048456     95.213853
# 36                  1137                    28300      0.038625     95.271257
#
#      Crime_Rate  Violent_Rate  Property_Rate Poverty_Group
# 0     13.542795      2.979415      10.563380   Low Poverty
# 1     24.096386      0.000000      24.096386   Low Poverty
# 2     13.451352      3.624198       9.827154   Low Poverty
# 3    135.531713     58.062480      77.469233      Moderate
# 4     15.693112      5.231037      10.462075          High
# 5    667.591308    258.437356     409.153953     Very High
# 6    381.241450    170.400137     210.841313     Very High
# 7    165.127549     46.905001     118.222547      Moderate
# 8     66.810849     18.646247      48.164601   Low Poverty
# 9    131.530550     46.182140      85.348410   Low Poverty
# 10    23.076578      7.393467      15.683112   Low Poverty
# 11   466.191067    178.349876     287.841191          High
# 12  1682.539683    453.968254    1228.571429   Low Poverty
# 13   394.096201    213.454075     180.642126     Very High
# 14   346.850422    171.152320     175.698102          High
# 15   365.465214    176.492503     188.972711     Very High
# 16   207.690912     63.032831     144.658081      Moderate
# 17   171.627969     68.995171     102.632798      Moderate
# 18   324.087024    146.853147     177.233877          High
# 19   111.655036     44.682846      66.972190      Moderate
# 20   136.868847     46.575632      90.293215      Moderate
# 21   117.121395     51.631843      65.489553      Moderate
# 22   166.374981     52.959976     113.415005   Low Poverty
# 23    61.002004     23.166333      37.835671   Low Poverty
# 24    68.058635     16.691303      51.367332   Low Poverty
# 25    42.566167     12.440542      30.125625   Low Poverty
# 26    81.250000     27.112676      54.137324   Low Poverty
# 27    63.210762     23.103139      40.107623   Low Poverty
# 29    64.187922     18.238935      45.948987   Low Poverty
# 30    39.716485     14.786753      24.929732   Low Poverty
# 31    38.026199      7.885031      30.141167   Low Poverty
# 32    40.690076     13.200314      27.489762   Low Poverty
# 33   138.313815     48.842760      89.471055   Low Poverty
# 34   123.499538     47.245306      76.254232   Low Poverty
# 35    60.941622     21.589685      39.351938   Low Poverty
# 36    32.578048      9.036247      23.541801   Low Poverty

# %%
plt.figure(figsize=(10,7))
plt.scatter(merged['Poverty_Rate'], merged['Violent_Rate'])
plt.xlabel("Poverty Rate")
plt.ylabel("Violent Crime Rate (per 1,000)")
plt.title("Poverty Rate vs Violent Crime Rate (Louisville 2020)")
plt.grid(True)
plt.show()

# %%
grouped = merged.groupby('Poverty_Group')['Crime_Rate'].mean()

plt.figure(figsize=(8,5))
grouped.plot(kind='bar')
plt.ylabel("Crime Rate per 1,000")
plt.title("Average Crime Rate by Poverty Level (Louisville, 2020)")
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# C:\Users\Joe\AppData\Local\Temp\ipykernel_11616\565019770.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = merged.groupby('Poverty_Group')['Crime_Rate'].mean()

# %%
plt.scatter(merged['Poverty_Rate'], merged['Property_Rate'])
plt.xlabel("Poverty Rate")
plt.ylabel("Property Crime Rate")
plt.title("Poverty vs Property Crime")
plt.show()

# %%
# Get counts of incidents by Crime_Type
crime_counts = crime_df['Crime_Type'].value_counts().reset_index()
crime_counts.columns = ['Crime_Type', 'Count']

# Create bar chart (Demonstrates Comparison)
plt.figure(figsize=(12, 6))
bars = plt.bar(crime_counts['Crime_Type'], crime_counts['Count'], color='skyblue', edgecolor='black')
plt.bar_label(bars, labels=crime_counts['Count'], label_type='edge')  # Add count labels on bars
plt.xticks(rotation=45, ha='right')
plt.xlabel('Crime Type', fontweight="bold")
plt.ylabel('Incident Count', fontweight="bold")
plt.title('Incident Counts by Crime Type, Louisville 2020')
plt.tight_layout()
plt.show()

# In this chart, I wanted to find the answer to the question, "How many incidents occurred per crime type reported in Louisville in 2020?"

# %%
# Count unique crime types per incident
crime_types_per_incident = crime_df.groupby('Incident_Number')['Crime_Type'].nunique()

# Create histogram (Demonstrates Distribution)
plt.figure(figsize=(8, 5))
counts, bins, patches = plt.hist(crime_types_per_incident, bins=range(1, int(crime_types_per_incident.max()) + 2), edgecolor='black', color='lightcoral', alpha=0.7)
plt.xticks(range(1, int(crime_types_per_incident.max()) + 1))
plt.xlabel('Number of Crime Types per Incident', fontweight="bold")
plt.ylabel('Number of Incidents', fontweight="bold")
plt.title('Crime Types per Incident, Louisville 2020')
plt.tight_layout()

# Add count labels on bars (optional, for clarity)
for i, count in enumerate(counts):
    if count > 0:
        plt.text(bins[i] + 0.5, count + 0.5, str(int(count)), ha='center', va='bottom')

plt.show()

# In this chart, I wanted to find the answer to the question, "How many crime types occurred per incident reported in Louisville in 2020?"

# %%
# Group by occurred day of week and count
dow_counts = crime_df.groupby('occurred_dow').size().reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']).reset_index(name='Incident_Count')

# Create line chart to establish relationship of number of incidents occurred by day of week
plt.figure(figsize=(10, 6))
plt.plot(dow_counts['occurred_dow'], dow_counts['Incident_Count'], marker='o', linestyle='-', color='green')

for x, y in zip(dow_counts['occurred_dow'], dow_counts['Incident_Count']):
    plt.text(x, y, f"{y:,}", ha="center", va="bottom", fontsize=10, fontweight="bold")

plt.xlabel('Day of Week', fontweight="bold")
plt.ylabel('Incident Count', fontweight="bold")
plt.title('Crime Incident Trend by Day of Week (Occurred), Louisville 2020')
plt.grid(True)
plt.ylim(bottom=9000, top=11000)
plt.show()

# In this chart, I wanted to know the answer to, "Does crime occur more frequently during the week (Mon-Fri) vs. the weekend (Sat/Sun)?"
